# %%
from pystac_client import Client
import planetary_computer

catalog = Client.open(
    "https://planetarycomputer.microsoft.com/api/stac/v1",
    modifier=planetary_computer.sign_inplace,
)

min_lon, min_lat, max_lon, max_lat = -123.5, 37.0, -121.5, 38.5
# Buscar colecciones relevantes por texto
for col in catalog.get_all_collections():
    if "Sentinel-2" in col.title or "Landsat" in col.title:
        print(col.id, col.title)


search = catalog.search(
    collections=["sentinel-2-l2a"],
    bbox=[min_lon, min_lat, max_lon, max_lat],
    datetime="2020-01-01/2020-12-31",
    query={"eo:cloud_cover": {"gt": 20}}  
)


items = list(search.get_items())
# Out:
# landsat-c2-l2 Landsat Collection 2 Level-2
# sentinel-2-l2a Sentinel-2 Level-2A
# landsat-c2-l1 Landsat Collection 2 Level-1
# hls2-s30 Harmonized Landsat Sentinel-2 (HLS) Version 2.0, Sentinel-2 Data
# hls2-l30 Harmonized Landsat Sentinel-2 (HLS) Version 2.0, Landsat Data
# C:\Users\Amalia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pystac_client\item_search.py:925: FutureWarning: get_items() is deprecated, use items() instead
#   warnings.warn(

# %%
import datetime

def buscar_pares_entrenamiento(bioma_nombre, coords, n_pares=50, dias_margen=30):
    buffer = 0.1
    bbox = [coords[0]-buffer, coords[1]-buffer, coords[0]+buffer, coords[1]+buffer]
    
    search_cloudy = catalog.search(
        collections=["sentinel-2-l2a"],
        bbox=bbox,
        datetime="2023-01-01/2023-12-31",
        query={"eo:cloud_cover": {"gt": 20, "lt": 60}}, 
        max_items=n_pares
    )
    cloudy_items = list(search_cloudy.items())

    pares = []
    for c_item in cloudy_items:
        # Extraer fecha de la imagen nublada
        fecha_nublada = c_item.datetime
        fecha_inicio = (fecha_nublada - datetime.timedelta(days=dias_margen)).strftime('%Y-%m-%dT%H:%M:%SZ')
        fecha_fin = (fecha_nublada + datetime.timedelta(days=dias_margen)).strftime('%Y-%m-%dT%H:%M:%SZ')

        # B. Buscamos la imagen limpia en ese rango específico de ±30 días
        search_clear = catalog.search(
            collections=["sentinel-2-l2a"],
            bbox=c_item.bbox,
            datetime=f"{fecha_inicio}/{fecha_fin}",
            query={"eo:cloud_cover": {"lt": 5}}, 
            max_items=1
        )
        clear_items = list(search_clear.items())
        
        if clear_items:
            pares.append({
                "bioma": bioma_nombre,
                "id_nublada": c_item.id,
                "id_limpia": clear_items[0].id,
                "nubes_porcentaje": c_item.properties["eo:cloud_cover"],
                "item_nublado": c_item,
                "item_limpio": clear_items[0]
            })
    return pares

# %%
import pandas as pd
'''
biomas = {
    "bosque": [-84.0, 10.3],
    "ciudad": [-74.0, 40.7],
    "desierto": [25.0, 25.0],
    "tundra": [68.0, 70.0],
    "sabana": [34.0, -1.3],
    "manglar": [-80.0, 0.5],
    "montaña": [86.9, 27.9],
    "pradera": [-100.0, 44.0],
    "humedal": [-58.0, -34.5],
    "agricultura": [-3.0, 40.0],
    "glaciar": [-72.0, -50.0],
    "volcanico": [-155.0, 19.4],
    "costa": [-77.0, 24.5],
    "isla_tropical": [-60.0, 14.0]
}

'''

biomas = {
    "bosque": [-60.0, -3.0],         
    "ciudad": [2.35, 48.86],          
    "desierto": [-13.0, 23.5],        
    "tundra": [30.0, 69.5],         
    "sabana": [20.0, 9.5],           
    "manglar": [99.0, 8.2],           
    "montaña": [7.0, 46.5],           
    "pradera": [105.0, 49.5],         
    "humedal": [-61.0, -32.0],        
    "agricultura": [-62.5, -31.0],    
    "glaciar": [13.0, 47.0],         
    "volcanico": [-78.6, -0.9],      
    "costa": [-8.9, 41.1],            
    "isla_tropical": [151.7, -16.9],  
    "oceano": [-40.0, 0.0],           
}


dataset_pares = []

for nombre, coords in biomas.items():
    print(f"Buscando pares para {nombre}...")
    dataset_pares.extend(buscar_pares_entrenamiento(nombre, coords, n_pares=100))

df_pares = pd.DataFrame(dataset_pares).drop(columns=['item_nublado', 'item_limpio'])
print(f"\nTotal de pares encontrados: {len(df_pares)}")
display(df_pares.head())


# Ejemplo: Analizar el primer par encontrado
ejemplo = dataset_pares[0]['item_nublado']
props = ejemplo.properties

print(f"Análisis del item: {ejemplo.id}")
print(f"- Nubes totales: {props.get('s2:cloud_shadow_percentage')}%")
print(f"- Nubes Cirrus (finas): {props.get('s2:thin_cirrus_percentage')}%")
print(f"- Sombras: {props.get('s2:cloud_shadow_percentage')}%")
# Out:
# Buscando pares para bosque...
# Buscando pares para ciudad...
# Buscando pares para desierto...
# Buscando pares para tundra...
# Buscando pares para sabana...
# Buscando pares para manglar...
# Buscando pares para montaña...
# Buscando pares para pradera...
# Buscando pares para humedal...
# Buscando pares para agricultura...
# Buscando pares para glaciar...
# Buscando pares para volcanico...
# Buscando pares para costa...
# Buscando pares para isla_tropical...
# Buscando pares para oceano...
#
# Total de pares encontrados: 813
#     bioma                                         id_nublada  \
# 0  bosque  S2A_MSIL2A_20231218T141711_R010_T20MRB_2023122...
# 1  bosque  S2B_MSIL2A_20231206T142709_R053_T20MRB_2024110...
# 2  bosque  S2B_MSIL2A_20231206T142709_R053_T20MRB_2023120...
# 3  bosque  S2A_MSIL2A_20231111T142711_R053_T20MRB_2024103...
# 4  bosque  S2A_MSIL2A_20231111T142711_R053_T20MRB_2023111...
#
#                                            id_limpia  nubes_porcentaje
# 0  S2B_MSIL2A_20231206T142709_R053_T20MRA_2023120...         23.725198
# 1  S2B_MSIL2A_20231206T142709_R053_T20MRA_2023120...         34.149659
# 2  S2B_MSIL2A_20231206T142709_R053_T20MRA_2023120...         34.701788
# 3  S2B_MSIL2A_20231206T142709_R053_T20MRA_2023120...         23.462209
# 4  S2B_MSIL2A_20231206T142709_R053_T20MRA_2023120...         23.513471
# Análisis del item: S2A_MSIL2A_20231218T141711_R010_T20MRB_20231220T103346
# - Nubes totales: 1.708466%
# - Nubes Cirrus (finas): 11.660299%
# - Sombras: 1.708466%

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import rioxarray
import numpy as np
import torchvision.transforms.functional as TF
import random

class CloudSegmentationDataset(Dataset):
    def __init__(self, df_pares, patch_size=256, train=True):
        self.df = df_pares
        self.patch_size = patch_size
        self.train = train
        self.bands = ["B04", "B03", "B02", "B08", "B11", "B12"]

    def __len__(self):
        return len(self.df)

    def transform(self, image, mask, target):
        # Image y Target son tensores (C, H, W). Mask es (1, H, W)
        if self.train:
            # Flip horizontal
            if random.random() > 0.5:
                image = TF.hflip(image)
                mask = TF.hflip(mask)
                target = TF.hflip(target)

            # Rotaciones de 90 grados
            angle = random.choice([0, 90, 180, 270])
            if angle != 0:
                image = TF.rotate(image, angle)
                mask = TF.rotate(mask, angle)
                target = TF.rotate(target, angle)

        return image, mask, target

    def _get_patch(self, item, is_mask=False):
        signed_item = planetary_computer.sign(item)
        if is_mask:
            url = signed_item.assets["SCL"].href
            da = rioxarray.open_rasterio(url)
            patch = da.isel(y=slice(0, self.patch_size), x=slice(0, self.patch_size)).values
            mask = np.isin(patch, [3, 8, 9, 10]).astype(np.float32)
            return torch.from_numpy(mask) # Retorna (1, H, W) o (H, W)
        else:
            band_data = []
            for b in self.bands:
                url = signed_item.assets[b].href
                da = rioxarray.open_rasterio(url)
                patch = da.isel(y=slice(0, self.patch_size), x=slice(0, self.patch_size)).values
                # Normalización robusta por banda: (x - min) / (max - min) aproximado
                # Sentinel-2 escala 0-10000, pero raramente pasa de 4000 en reflectancia
                patch = np.clip(patch / 4000.0, 0, 1)
                band_data.append(patch)

            img = np.concatenate(band_data, axis=0).astype(np.float32)
            return torch.from_numpy(img)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]

        img_input = self._get_patch(row['item_nublado'], is_mask=False)
        mask = self._get_patch(row['item_nublado'], is_mask=True)
        img_target = self._get_patch(row['item_limpio'], is_mask=False)

        # Aplicar aumentos de datos de forma consistente a los 3 elementos
        img_input, mask, img_target = self.transform(img_input, mask, img_target)

        return {
            "input": img_input,   # Para Modelo A y B
            "mask": mask,         # Target para Modelo A, Input para Modelo B
            "target": img_target  # Target para Modelo B
        }

# Crear el DataLoader
train_ds = CloudSegmentationDataset(df_pares)
train_loader = DataLoader(train_ds, batch_size=8, shuffle=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import torch
#       2 from torch.utils.data import Dataset, DataLoader
#       3 import rioxarray
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\__init__.py:2247
#    2231 ################################################################################
#    2232 # Import most common subpackages
#    2233 ################################################################################
#    (...)
#    2238
#    2239 # needs to be before import torch.nn as nn to avoid circular dependencies
#    2240 from torch.autograd import (  # usort: skip
#    2241     enable_grad as enable_grad,
#    2242     inference_mode as inference_mode,
#    2243     no_grad as no_grad,
#    2244     set_grad_enabled as set_grad_enabled,
#    2245 )
# -> 2247 from torch import (
#    2248     __config__ as __config__,
#    2249     __future__ as __future__,
#    2250     _awaits as _awaits,
#    2251     accelerator as accelerator,
#    2252     autograd as autograd,
#    2253     backends as backends,
#    2254     cpu as cpu,
#    2255     cuda as cuda,
#    2256     distributed as distributed,
#    2257     distributions as distributions,
#    2258     fft as fft,
#    2259     futures as futures,
#    2260     hub as hub,
#    2261     jit as jit,
#    2262     linalg as linalg,
#    2263     mps as mps,
#    2264     mtia as mtia,
#    2265     multiprocessing as multiprocessing,
#    2266     nested as nested,
#    2267     nn as nn,
#    2268     optim as optim,
#    2269     overrides as overrides,
#    2270     profiler as profiler,
#    2271     sparse as sparse,
#    2272     special as special,
#    2273     testing as testing,
#    2274     types as types,
#    2275     utils as utils,
#    2276     version as version,
#    2277     xpu as xpu,
#    2278 )
#    2279 from torch.signal import windows as windows
#    2282 # Quantized, sparse, AO, etc. should be last to get imported, as nothing
#    2283 # is expected to depend on them.
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\profiler\__init__.py:17
#      15 from torch._C._autograd import _supported_activities, DeviceType, kineto_available
#      16 from torch._C._profiler import _ExperimentalConfig, ProfilerActivity, RecordScope
# ---> 17 from torch._environment import is_fbcode
#      18 from torch.autograd.profiler import KinetoStepTracker, record_function
#      19 from torch.optim.optimizer import Optimizer, register_optimizer_step_post_hook
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1147, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:936, in exec_module(self, module)
#
# File <frozen importlib._bootstrap_external>:1032, in get_code(self, fullname)
#
# File <frozen importlib._bootstrap_external>:1130, in get_data(self, path)
#
# KeyboardInterrupt:

# %%
# Verifica que cada fila tenga un ID distinto pero cercano
print(df_pares[['id_nublada', 'id_limpia', 'nubes_porcentaje']].head(11))

# Cuenta cuántos pares tienes por cada tipo de bioma
print(df_pares['bioma'].value_counts())
# Out:
#                                            id_nublada  \
# 0   S2A_MSIL2A_20231218T141711_R010_T20MRB_2023122...
# 1   S2B_MSIL2A_20231206T142709_R053_T20MRB_2024110...
# 2   S2B_MSIL2A_20231206T142709_R053_T20MRB_2023120...
# 3   S2A_MSIL2A_20231111T142711_R053_T20MRB_2024103...
# 4   S2A_MSIL2A_20231111T142711_R053_T20MRB_2023111...
# 5   S2A_MSIL2A_20231029T141711_R010_T20MRB_2023102...
# 6   S2A_MSIL2A_20231019T141711_R010_T20MRB_2024092...
# 7   S2A_MSIL2A_20231019T141711_R010_T20MRB_2023101...
# 8   S2B_MSIL2A_20231017T142719_R053_T20MRB_2024110...
# 9   S2B_MSIL2A_20231017T142719_R053_T20MRB_2023101...
# 10  S2A_MSIL2A_20230929T141711_R010_T20MRB_2023092...
#
#                                             id_limpia  nubes_porcentaje
# 0   S2B_MSIL2A_20231206T142709_R053_T20MRA_2023120...         23.725198
# 1   S2B_MSIL2A_20231206T142709_R053_T20MRA_2023120...         34.149659
# 2   S2B_MSIL2A_20231206T142709_R053_T20MRA_2023120...         34.701788
# 3   S2B_MSIL2A_20231206T142709_R053_T20MRA_2023120...         23.462209
# 4   S2B_MSIL2A_20231206T142709_R053_T20MRA_2023120...         23.513471
# 5   S2A_MSIL2A_20231128T141701_R010_T20MRB_2024111...         21.148255
# 6   S2B_MSIL2A_20231116T142709_R053_T20MRC_2024110...         41.695356
# 7   S2B_MSIL2A_20231116T142709_R053_T20MRC_2024110...         42.456111
# 8   S2B_MSIL2A_20231116T142709_R053_T20MRC_2024110...         28.307888
# 9   S2B_MSIL2A_20231116T142709_R053_T20MRC_2024110...         28.358117
# 10  S2A_MSIL2A_20231009T141711_R010_T21MTT_2024110...         25.208613
# bioma
# pradera          100
# glaciar          100
# costa            100
# tundra            97
# manglar           77
# montaña           66
# sabana            55
# bosque            48
# desierto          46
# ciudad            43
# isla_tropical     42
# humedal           23
# agricultura       10
# volcanico          6
# Name: count, dtype: int64

# %% [markdown]
# ## Guardar pares y parches
#
# Funciones para guardar metadata de pares y (opcional) descargar parches centrados para uso en entrenamiento.

# %%
import os
import numpy as np
import rioxarray
import planetary_computer
import pandas as pd

def save_pairs_metadata(pares, out_csv="pares_metadata.csv"):
    rows = []
    for p in pares:
        try:
            n = planetary_computer.sign(p["item_nublado"])
            l = planetary_computer.sign(p["item_limpio"])
        except Exception:
            n = p.get("item_nublado")
            l = p.get("item_limpio")
        rows.append({
            "bioma": p.get("bioma"),
            "id_nublada": p.get("id_nublada"),
            "id_limpia": p.get("id_limpia"),
            "nubes_porcentaje": p.get("nubes_porcentaje"),
            "nublado_B04": n.assets.get("B04").href if n and "B04" in getattr(n, 'assets', {}) else None,
            "nublado_SCL": n.assets.get("SCL").href if n and "SCL" in getattr(n, 'assets', {}) else None,
            "limpio_B04": l.assets.get("B04").href if l and "B04" in getattr(l, 'assets', {}) else None,
        })
    pd.DataFrame(rows).to_csv(out_csv, index=False)
    print(f"Metadata guardada en {out_csv}")

def save_center_patch(item, out_path, bands=["B04","B03","B02"], patch_size=256):

    planetary_computer.sign_inplace(item)  

    with rioxarray.open_rasterio(item.assets[bands[0]].href) as ref:
        cy, cx = ref.shape[1] // 2, ref.shape[2] // 2

    band_arrays = []

    for b in bands:
        with rioxarray.open_rasterio(item.assets[b].href) as da:
            patch = da.isel(
                y=slice(cy, cy + patch_size),
                x=slice(cx, cx + patch_size)
            ).values
            band_arrays.append(patch)

    arr = np.concatenate(band_arrays, axis=0).astype(np.float32)
    np.save(out_path, arr)

def download_all_pairs(pares, out_root="pairs_patches", patch_size=256, max_pairs=None, start_from=0):
    os.makedirs(out_root, exist_ok=True)
    end_at = len(pares) if max_pairs is None else min(len(pares), start_from + max_pairs)
    for i in range(start_from, end_at):
        p = pares[i]
        name = f"{i}_{p.get('bioma','')}_{p.get('id_nublada','')}".replace(' ', '_')
        dir_out = os.path.join(out_root, name)
        # Verificar si ya existe (ya descargado)
        if os.path.exists(dir_out) and os.path.isfile(os.path.join(dir_out, "input.npy")):
            print(f"Par {i} ya descargado, saltando...")
            continue
        os.makedirs(dir_out, exist_ok=True)
        try:
            save_center_patch(p["item_nublado"], os.path.join(dir_out, "input.npy"), patch_size=patch_size)
            save_center_patch(p["item_limpio"], os.path.join(dir_out, "target.npy"), patch_size=patch_size)
            try:
                save_center_patch(p["item_nublado"], os.path.join(dir_out, "scl.npy"), bands=["SCL"], patch_size=patch_size)
            except Exception:
                pass
            print(f"Par {i} descargado exitosamente.")
        except Exception as e:
            print(f"Error guardando par {i}: {e}")

# Ejemplo: guardar metadata y descargar 20 pares (descomenta para ejecutar)
save_pairs_metadata(dataset_pares, out_csv="pares_metadata_v2.csv")
# Para continuar desde donde se quedó, encuentra el último índice descargado
# Por ejemplo, si se quedó en 50, usa start_from=50
download_all_pairs(dataset_pares, out_root="pairs_patches_sample_v2", patch_size=256, max_pairs=800, start_from=107)
# Out:
# Metadata guardada en pares_metadata_v2.csv
# Par 107 ya descargado, saltando...
# Par 108 descargado exitosamente.
# Par 109 descargado exitosamente.
# Par 110 descargado exitosamente.
# Par 111 descargado exitosamente.
# Par 112 descargado exitosamente.
# Par 113 descargado exitosamente.
# Par 114 descargado exitosamente.
# Par 115 descargado exitosamente.
# Error guardando par 116: HTTP response code: 403
# Error guardando par 117: HTTP response code: 403
# Error guardando par 118: HTTP response code: 403
# Error guardando par 119: HTTP response code: 403
# Error guardando par 120: HTTP response code: 403
# Error guardando par 121: HTTP response code: 403
# Error guardando par 122: HTTP response code: 403
# Error guardando par 123: HTTP response code: 403
# Error guardando par 124: HTTP response code: 403
# Error guardando par 125: HTTP response code: 403
# Error guardando par 126: HTTP response code: 403
# Error guardando par 127: HTTP response code: 403
# Error guardando par 128: HTTP response code: 403
# Error guardando par 129: HTTP response code: 403
# Error guardando par 130: HTTP response code: 403
# Error guardando par 131: HTTP response code: 403
# Error guardando par 132: HTTP response code: 403
# Error guardando par 133: HTTP response code: 403
# Error guardando par 134: HTTP response code: 403
# Error guardando par 135: HTTP response code: 403
# Error guardando par 136: HTTP response code: 403
# Error guardando par 137: HTTP response code: 403
# Error guardando par 138: HTTP response code: 403
# Error guardando par 139: HTTP response code: 403
# Error guardando par 140: HTTP response code: 403
# Error guardando par 141: HTTP response code: 403
# Error guardando par 142: HTTP response code: 403
# Error guardando par 143: HTTP response code: 403
# Error guardando par 144: HTTP response code: 403
# Error guardando par 145: HTTP response code: 403
# Error guardando par 146: HTTP response code: 403
# Error guardando par 147: HTTP response code: 403
# Error guardando par 148: HTTP response code: 403
# Error guardando par 149: HTTP response code: 403
# Error guardando par 150: HTTP response code: 403
# Error guardando par 151: HTTP response code: 403
# Error guardando par 152: HTTP response code: 403
# Error guardando par 153: HTTP response code: 403
# Error guardando par 154: HTTP response code: 403
# Error guardando par 155: HTTP response code: 403
# Error guardando par 156: HTTP response code: 403
# Error guardando par 157: HTTP response code: 403
# Error guardando par 158: HTTP response code: 403
# Error guardando par 159: HTTP response code: 403
# Error guardando par 160: HTTP response code: 403
# Error guardando par 161: HTTP response code: 403
# Error guardando par 162: HTTP response code: 403
# Error guardando par 163: HTTP response code: 403
# Error guardando par 164: HTTP response code: 403
# Error guardando par 165: HTTP response code: 403
# Error guardando par 166: HTTP response code: 403
# Error guardando par 167: HTTP response code: 403
# Error guardando par 168: HTTP response code: 403
# Error guardando par 169: HTTP response code: 403
# Error guardando par 170: HTTP response code: 403
# Error guardando par 171: HTTP response code: 403
# Error guardando par 172: HTTP response code: 403
# Error guardando par 173: HTTP response code: 403
# Error guardando par 174: HTTP response code: 403
# Error guardando par 175: HTTP response code: 403
# Error guardando par 176: HTTP response code: 403
# Error guardando par 177: HTTP response code: 403
# Error guardando par 178: HTTP response code: 403
# Error guardando par 179: HTTP response code: 403
# Error guardando par 180: HTTP response code: 403
# Error guardando par 181: HTTP response code: 403
# Error guardando par 182: HTTP response code: 403
# Error guardando par 183: HTTP response code: 403
# Error guardando par 184: HTTP response code: 403
# Error guardando par 185: HTTP response code: 403
# Error guardando par 186: HTTP response code: 403
# Error guardando par 187: HTTP response code: 403
# Error guardando par 188: HTTP response code: 403
# Error guardando par 189: HTTP response code: 403
# Error guardando par 190: HTTP response code: 403
# Error guardando par 191: HTTP response code: 403
# Error guardando par 192: HTTP response code: 403
# Error guardando par 193: HTTP response code: 403
# Error guardando par 194: HTTP response code: 403
# Error guardando par 195: HTTP response code: 403
# Error guardando par 196: HTTP response code: 403
# Error guardando par 197: HTTP response code: 403
# Error guardando par 198: HTTP response code: 403
# Error guardando par 199: HTTP response code: 403
# Error guardando par 200: HTTP response code: 403
# Error guardando par 201: HTTP response code: 403
# Error guardando par 202: HTTP response code: 403
# Error guardando par 203: HTTP response code: 403
# Error guardando par 204: HTTP response code: 403
# Error guardando par 205: HTTP response code: 403
# Error guardando par 206: HTTP response code: 403
# Error guardando par 207: HTTP response code: 403
# Error guardando par 208: HTTP response code: 403
# Error guardando par 209: HTTP response code: 403
# Error guardando par 210: HTTP response code: 403
# Error guardando par 211: HTTP response code: 403
# Error guardando par 212: HTTP response code: 403
# Error guardando par 213: HTTP response code: 403
# Error guardando par 214: HTTP response code: 403
# Error guardando par 215: HTTP response code: 403
# Error guardando par 216: HTTP response code: 403
# Error guardando par 217: HTTP response code: 403
# Error guardando par 218: HTTP response code: 403
# Error guardando par 219: HTTP response code: 403
# Error guardando par 220: HTTP response code: 403
# Error guardando par 221: HTTP response code: 403
# Error guardando par 222: HTTP response code: 403
# Error guardando par 223: HTTP response code: 403
# Error guardando par 224: HTTP response code: 403
# Error guardando par 225: HTTP response code: 403
# Error guardando par 226: HTTP response code: 403
# Error guardando par 227: HTTP response code: 403
# Error guardando par 228: HTTP response code: 403
# Error guardando par 229: HTTP response code: 403
# Error guardando par 230: HTTP response code: 403
# Error guardando par 231: HTTP response code: 403
# Error guardando par 232: HTTP response code: 403
# Error guardando par 233: HTTP response code: 403
# Error guardando par 234: HTTP response code: 403
# Error guardando par 235: HTTP response code: 403
# Error guardando par 236: HTTP response code: 403
# Error guardando par 237: HTTP response code: 403
# Error guardando par 238: HTTP response code: 403
# Error guardando par 239: HTTP response code: 403
# Error guardando par 240: HTTP response code: 403
# Error guardando par 241: HTTP response code: 403
# Error guardando par 242: HTTP response code: 403
# Error guardando par 243: HTTP response code: 403
# Error guardando par 244: HTTP response code: 403
# Error guardando par 245: HTTP response code: 403
# Error guardando par 246: HTTP response code: 403
# Error guardando par 247: HTTP response code: 403
# Error guardando par 248: HTTP response code: 403
# Error guardando par 249: HTTP response code: 403
# Error guardando par 250: HTTP response code: 403
# Error guardando par 251: HTTP response code: 403
# Error guardando par 252: HTTP response code: 403
# Error guardando par 253: HTTP response code: 403
# Error guardando par 254: HTTP response code: 403
# Error guardando par 255: HTTP response code: 403
# Error guardando par 256: HTTP response code: 403
# Error guardando par 257: HTTP response code: 403
# Error guardando par 258: HTTP response code: 403
# Error guardando par 259: HTTP response code: 403
# Error guardando par 260: HTTP response code: 403
# Error guardando par 261: HTTP response code: 403
# Error guardando par 262: HTTP response code: 403
# Error guardando par 263: HTTP response code: 403
# Error guardando par 264: HTTP response code: 403
# Error guardando par 265: HTTP response code: 403
# Error guardando par 266: HTTP response code: 403
# Error guardando par 267: HTTP response code: 403
# Error guardando par 268: HTTP response code: 403
# Error guardando par 269: HTTP response code: 403
# Error guardando par 270: HTTP response code: 403
# Error guardando par 271: HTTP response code: 403
# Error guardando par 272: HTTP response code: 403
# Error guardando par 273: HTTP response code: 403
# Error guardando par 274: HTTP response code: 403
# Error guardando par 275: HTTP response code: 403
# Error guardando par 276: HTTP response code: 403
# Error guardando par 277: HTTP response code: 403
# Error guardando par 278: HTTP response code: 403
# Error guardando par 279: HTTP response code: 403
# Error guardando par 280: HTTP response code: 403
# Error guardando par 281: HTTP response code: 403
# Error guardando par 282: HTTP response code: 403
# Error guardando par 283: HTTP response code: 403
# Error guardando par 284: HTTP response code: 403
# Error guardando par 285: HTTP response code: 403
# Error guardando par 286: HTTP response code: 403
# Error guardando par 287: HTTP response code: 403
# Error guardando par 288: HTTP response code: 403
# Error guardando par 289: HTTP response code: 403
# Error guardando par 290: HTTP response code: 403
# Error guardando par 291: HTTP response code: 403
# Error guardando par 292: HTTP response code: 403
# Error guardando par 293: HTTP response code: 403
# Error guardando par 294: HTTP response code: 403
# Error guardando par 295: HTTP response code: 403
# Error guardando par 296: HTTP response code: 403
# Error guardando par 297: HTTP response code: 403
# Error guardando par 298: HTTP response code: 403
# Error guardando par 299: HTTP response code: 403
# Error guardando par 300: HTTP response code: 403
# Error guardando par 301: HTTP response code: 403
# Error guardando par 302: HTTP response code: 403
# Error guardando par 303: HTTP response code: 403
# Error guardando par 304: HTTP response code: 403
# Error guardando par 305: HTTP response code: 403
# Error guardando par 306: HTTP response code: 403
# Error guardando par 307: HTTP response code: 403
# Error guardando par 308: HTTP response code: 403
# Error guardando par 309: HTTP response code: 403
# Error guardando par 310: HTTP response code: 403
# Error guardando par 311: HTTP response code: 403
# Error guardando par 312: HTTP response code: 403
# Error guardando par 313: HTTP response code: 403
# Error guardando par 314: HTTP response code: 403
# Error guardando par 315: HTTP response code: 403
# Error guardando par 316: HTTP response code: 403
# Error guardando par 317: HTTP response code: 403
# Error guardando par 318: HTTP response code: 403
# Error guardando par 319: HTTP response code: 403
# Error guardando par 320: HTTP response code: 403
# Error guardando par 321: HTTP response code: 403
# Error guardando par 322: HTTP response code: 403
# Error guardando par 323: HTTP response code: 403
# Error guardando par 324: HTTP response code: 403
# Error guardando par 325: HTTP response code: 403
# Error guardando par 326: HTTP response code: 403
# Error guardando par 327: HTTP response code: 403
# Error guardando par 328: HTTP response code: 403
# Error guardando par 329: HTTP response code: 403
# Error guardando par 330: HTTP response code: 403
# Error guardando par 331: HTTP response code: 403
# Error guardando par 332: HTTP response code: 403
# Error guardando par 333: HTTP response code: 403
# Error guardando par 334: HTTP response code: 403
# Error guardando par 335: HTTP response code: 403
# Error guardando par 336: HTTP response code: 403
# Error guardando par 337: HTTP response code: 403
# Error guardando par 338: HTTP response code: 403
# Error guardando par 339: HTTP response code: 403
# Error guardando par 340: HTTP response code: 403
# Error guardando par 341: HTTP response code: 403
# Error guardando par 342: HTTP response code: 403
# Error guardando par 343: HTTP response code: 403
# Error guardando par 344: HTTP response code: 403
# Error guardando par 345: HTTP response code: 403
# Error guardando par 346: HTTP response code: 403
# Error guardando par 347: HTTP response code: 403
# Error guardando par 348: HTTP response code: 403
# Error guardando par 349: HTTP response code: 403
# Error guardando par 350: HTTP response code: 403
# Error guardando par 351: HTTP response code: 403
# Error guardando par 352: HTTP response code: 403
# Error guardando par 353: HTTP response code: 403
# Error guardando par 354: HTTP response code: 403
# Error guardando par 355: HTTP response code: 403
# Error guardando par 356: HTTP response code: 403
# Error guardando par 357: HTTP response code: 403
# Error guardando par 358: HTTP response code: 403
# Error guardando par 359: HTTP response code: 403
# Error guardando par 360: HTTP response code: 403
# Error guardando par 361: HTTP response code: 403
# Error guardando par 362: HTTP response code: 403
# Error guardando par 363: HTTP response code: 403
# Error guardando par 364: HTTP response code: 403
# Error guardando par 365: HTTP response code: 403
# Error guardando par 366: HTTP response code: 403
# Error guardando par 367: HTTP response code: 403
# Error guardando par 368: HTTP response code: 403
# Error guardando par 369: HTTP response code: 403
# Error guardando par 370: HTTP response code: 403
# Error guardando par 371: HTTP response code: 403
# Error guardando par 372: HTTP response code: 403
# Error guardando par 373: HTTP response code: 403
# Error guardando par 374: HTTP response code: 403
# Error guardando par 375: HTTP response code: 403
# Error guardando par 376: HTTP response code: 403
# Error guardando par 377: HTTP response code: 403
# Error guardando par 378: HTTP response code: 403
# Error guardando par 379: HTTP response code: 403
# Error guardando par 380: HTTP response code: 403
# Error guardando par 381: HTTP response code: 403
# Error guardando par 382: HTTP response code: 403
# Error guardando par 383: HTTP response code: 403
# Error guardando par 384: HTTP response code: 403
# Error guardando par 385: HTTP response code: 403
# Error guardando par 386: HTTP response code: 403
# Error guardando par 387: HTTP response code: 403
# Error guardando par 388: HTTP response code: 403
# Error guardando par 389: HTTP response code: 403
# Error guardando par 390: HTTP response code: 403
# Error guardando par 391: HTTP response code: 403
# Error guardando par 392: HTTP response code: 403
# Error guardando par 393: HTTP response code: 403
# Error guardando par 394: HTTP response code: 403
# Error guardando par 395: HTTP response code: 403
# Error guardando par 396: HTTP response code: 403
# Error guardando par 397: HTTP response code: 403
# Error guardando par 398: HTTP response code: 403
# Error guardando par 399: HTTP response code: 403
# Error guardando par 400: HTTP response code: 403
# Error guardando par 401: HTTP response code: 403
# Error guardando par 402: HTTP response code: 403
# Error guardando par 403: HTTP response code: 403
# Error guardando par 404: HTTP response code: 403
# Error guardando par 405: HTTP response code: 403
# Error guardando par 406: HTTP response code: 403
# Error guardando par 407: HTTP response code: 403
# Error guardando par 408: HTTP response code: 403
# Error guardando par 409: HTTP response code: 403
# Error guardando par 410: HTTP response code: 403
# Error guardando par 411: HTTP response code: 403
# Error guardando par 412: HTTP response code: 403
# Error guardando par 413: HTTP response code: 403
# Error guardando par 414: HTTP response code: 403
# Error guardando par 415: HTTP response code: 403
# Error guardando par 416: HTTP response code: 403
# Error guardando par 417: HTTP response code: 403
# Error guardando par 418: HTTP response code: 403
# Error guardando par 419: HTTP response code: 403
# Error guardando par 420: HTTP response code: 403
# Error guardando par 421: HTTP response code: 403
# Error guardando par 422: HTTP response code: 403
# Error guardando par 423: HTTP response code: 403
# Error guardando par 424: HTTP response code: 403
# Error guardando par 425: HTTP response code: 403
# Error guardando par 426: HTTP response code: 403
# Error guardando par 427: HTTP response code: 403
# Error guardando par 428: HTTP response code: 403
# Error guardando par 429: HTTP response code: 403
# Error guardando par 430: HTTP response code: 403
# Error guardando par 431: HTTP response code: 403
# Error guardando par 432: HTTP response code: 403
# Error guardando par 433: HTTP response code: 403
# Error guardando par 434: HTTP response code: 403
# Error guardando par 435: HTTP response code: 403
# Error guardando par 436: HTTP response code: 403
# Error guardando par 437: HTTP response code: 403
# Error guardando par 438: HTTP response code: 403
# Error guardando par 439: HTTP response code: 403
# Error guardando par 440: HTTP response code: 403
# Error guardando par 441: HTTP response code: 403
# Error guardando par 442: HTTP response code: 403
# Error guardando par 443: HTTP response code: 403
# Error guardando par 444: HTTP response code: 403
# Error guardando par 445: HTTP response code: 403
# Error guardando par 446: HTTP response code: 403
# Error guardando par 447: HTTP response code: 403
# Error guardando par 448: HTTP response code: 403
# Error guardando par 449: HTTP response code: 403
# Error guardando par 450: HTTP response code: 403
# Error guardando par 451: HTTP response code: 403
# Error guardando par 452: HTTP response code: 403
# Error guardando par 453: HTTP response code: 403
# Error guardando par 454: HTTP response code: 403
# Error guardando par 455: HTTP response code: 403
# Error guardando par 456: HTTP response code: 403
# Error guardando par 457: HTTP response code: 403
# Error guardando par 458: HTTP response code: 403
# Error guardando par 459: HTTP response code: 403
# Error guardando par 460: HTTP response code: 403
# Error guardando par 461: HTTP response code: 403
# Error guardando par 462: HTTP response code: 403
# Error guardando par 463: HTTP response code: 403
# Error guardando par 464: HTTP response code: 403
# Error guardando par 465: HTTP response code: 403
# Error guardando par 466: HTTP response code: 403
# Error guardando par 467: HTTP response code: 403
# Error guardando par 468: HTTP response code: 403
# Error guardando par 469: HTTP response code: 403
# Error guardando par 470: HTTP response code: 403
# Error guardando par 471: HTTP response code: 403
# Error guardando par 472: HTTP response code: 403
# Error guardando par 473: HTTP response code: 403
# Error guardando par 474: HTTP response code: 403
# Error guardando par 475: HTTP response code: 403
# Error guardando par 476: HTTP response code: 403
# Error guardando par 477: HTTP response code: 403
# Error guardando par 478: HTTP response code: 403
# Error guardando par 479: HTTP response code: 403
# Error guardando par 480: HTTP response code: 403
# Error guardando par 481: HTTP response code: 403
# Error guardando par 482: HTTP response code: 403
# Error guardando par 483: HTTP response code: 403
# Error guardando par 484: HTTP response code: 403
# Error guardando par 485: HTTP response code: 403
# Error guardando par 486: HTTP response code: 403
# Error guardando par 487: HTTP response code: 403
# Error guardando par 488: HTTP response code: 403
# Error guardando par 489: HTTP response code: 403
# Error guardando par 490: HTTP response code: 403
# Error guardando par 491: HTTP response code: 403
# Error guardando par 492: HTTP response code: 403
# Error guardando par 493: HTTP response code: 403
# Error guardando par 494: HTTP response code: 403
# Error guardando par 495: HTTP response code: 403
# Error guardando par 496: HTTP response code: 403
# Error guardando par 497: HTTP response code: 403
# Error guardando par 498: HTTP response code: 403
# Error guardando par 499: HTTP response code: 403
# Error guardando par 500: HTTP response code: 403
# Error guardando par 501: HTTP response code: 403
# Error guardando par 502: HTTP response code: 403
# Error guardando par 503: HTTP response code: 403
# Error guardando par 504: HTTP response code: 403
# Error guardando par 505: HTTP response code: 403
# Error guardando par 506: HTTP response code: 403
# Error guardando par 507: HTTP response code: 403
# Error guardando par 508: HTTP response code: 403
# Error guardando par 509: HTTP response code: 403
# Error guardando par 510: HTTP response code: 403
# Error guardando par 511: HTTP response code: 403
# Error guardando par 512: HTTP response code: 403
# Error guardando par 513: HTTP response code: 403
# Error guardando par 514: HTTP response code: 403
# Error guardando par 515: HTTP response code: 403
# Error guardando par 516: HTTP response code: 403
# Error guardando par 517: HTTP response code: 403
# Error guardando par 518: HTTP response code: 403
# Error guardando par 519: HTTP response code: 403
# Error guardando par 520: HTTP response code: 403
# Error guardando par 521: HTTP response code: 403
# Error guardando par 522: HTTP response code: 403
# Error guardando par 523: HTTP response code: 403
# Error guardando par 524: HTTP response code: 403
# Error guardando par 525: HTTP response code: 403
# Error guardando par 526: HTTP response code: 403
# Error guardando par 527: HTTP response code: 403
# Error guardando par 528: HTTP response code: 403
# Error guardando par 529: HTTP response code: 403
# Error guardando par 530: HTTP response code: 403
# Error guardando par 531: HTTP response code: 403
# Error guardando par 532: HTTP response code: 403
# Error guardando par 533: HTTP response code: 403
# Error guardando par 534: HTTP response code: 403
# Error guardando par 535: HTTP response code: 403
# Error guardando par 536: HTTP response code: 403
# Error guardando par 537: HTTP response code: 403
# Error guardando par 538: HTTP response code: 403
# Error guardando par 539: HTTP response code: 403
# Error guardando par 540: HTTP response code: 403
# Error guardando par 541: HTTP response code: 403
# Error guardando par 542: HTTP response code: 403
# Error guardando par 543: HTTP response code: 403
# Error guardando par 544: HTTP response code: 403
# Error guardando par 545: HTTP response code: 403
# Error guardando par 546: HTTP response code: 403
# Error guardando par 547: HTTP response code: 403
# Error guardando par 548: HTTP response code: 403
# Error guardando par 549: HTTP response code: 403
# Error guardando par 550: HTTP response code: 403
# Error guardando par 551: HTTP response code: 403
# Error guardando par 552: HTTP response code: 403
# Error guardando par 553: HTTP response code: 403
# Error guardando par 554: HTTP response code: 403
# Error guardando par 555: HTTP response code: 403
# Error guardando par 556: HTTP response code: 403
# Error guardando par 557: HTTP response code: 403
# Error guardando par 558: HTTP response code: 403
# Error guardando par 559: HTTP response code: 403
# Error guardando par 560: HTTP response code: 403
# Error guardando par 561: HTTP response code: 403
# Error guardando par 562: HTTP response code: 403
# Error guardando par 563: HTTP response code: 403
# Error guardando par 564: HTTP response code: 403
# Error guardando par 565: HTTP response code: 403
# Error guardando par 566: HTTP response code: 403
# Error guardando par 567: HTTP response code: 403
# Error guardando par 568: HTTP response code: 403
# Error guardando par 569: HTTP response code: 403
# Error guardando par 570: HTTP response code: 403
# Error guardando par 571: HTTP response code: 403
# Error guardando par 572: HTTP response code: 403
# Error guardando par 573: HTTP response code: 403
# Error guardando par 574: HTTP response code: 403
# Error guardando par 575: HTTP response code: 403
# Error guardando par 576: HTTP response code: 403
# Error guardando par 577: HTTP response code: 403
# Error guardando par 578: HTTP response code: 403
# Error guardando par 579: HTTP response code: 403
# Error guardando par 580: HTTP response code: 403
# Error guardando par 581: HTTP response code: 403
# Error guardando par 582: HTTP response code: 403
# Error guardando par 583: HTTP response code: 403
# Error guardando par 584: HTTP response code: 403
# Error guardando par 585: HTTP response code: 403
# Error guardando par 586: HTTP response code: 403
# Error guardando par 587: HTTP response code: 403
# Error guardando par 588: HTTP response code: 403
# Error guardando par 589: HTTP response code: 403
# Error guardando par 590: HTTP response code: 403
# Error guardando par 591: HTTP response code: 403
# Error guardando par 592: HTTP response code: 403
# Error guardando par 593: HTTP response code: 403
# Error guardando par 594: HTTP response code: 403
# Error guardando par 595: HTTP response code: 403
# Error guardando par 596: HTTP response code: 403
# Error guardando par 597: HTTP response code: 403
# Error guardando par 598: HTTP response code: 403
# Error guardando par 599: HTTP response code: 403
# Error guardando par 600: HTTP response code: 403
# Error guardando par 601: HTTP response code: 403
# Error guardando par 602: HTTP response code: 403
# Error guardando par 603: HTTP response code: 403
# Error guardando par 604: HTTP response code: 403
# Error guardando par 605: HTTP response code: 403
# Error guardando par 606: HTTP response code: 403
# Error guardando par 607: HTTP response code: 403
# Error guardando par 608: HTTP response code: 403
# Error guardando par 609: HTTP response code: 403
# Error guardando par 610: HTTP response code: 403
# Error guardando par 611: HTTP response code: 403
# Error guardando par 612: HTTP response code: 403
# Error guardando par 613: HTTP response code: 403
# Error guardando par 614: HTTP response code: 403
# Error guardando par 615: HTTP response code: 403
# Error guardando par 616: HTTP response code: 403
# Error guardando par 617: HTTP response code: 403
# Error guardando par 618: HTTP response code: 403
# Error guardando par 619: HTTP response code: 403
# Error guardando par 620: HTTP response code: 403
# Error guardando par 621: HTTP response code: 403
# Error guardando par 622: HTTP response code: 403
# Error guardando par 623: HTTP response code: 403
# Error guardando par 624: HTTP response code: 403
# Error guardando par 625: HTTP response code: 403
# Error guardando par 626: HTTP response code: 403
# Error guardando par 627: HTTP response code: 403
# Error guardando par 628: HTTP response code: 403
# Error guardando par 629: HTTP response code: 403
# Error guardando par 630: HTTP response code: 403
# Error guardando par 631: HTTP response code: 403
# Error guardando par 632: HTTP response code: 403
# Error guardando par 633: HTTP response code: 403
# Error guardando par 634: HTTP response code: 403
# Error guardando par 635: HTTP response code: 403
# Error guardando par 636: HTTP response code: 403
# Error guardando par 637: HTTP response code: 403
# Error guardando par 638: HTTP response code: 403
# Error guardando par 639: HTTP response code: 403
# Error guardando par 640: HTTP response code: 403
# Error guardando par 641: HTTP response code: 403
# Error guardando par 642: HTTP response code: 403
# Error guardando par 643: HTTP response code: 403
# Error guardando par 644: HTTP response code: 403
# Error guardando par 645: HTTP response code: 403
# Error guardando par 646: HTTP response code: 403
# Error guardando par 647: HTTP response code: 403
# Error guardando par 648: HTTP response code: 403
# Error guardando par 649: HTTP response code: 403
# Error guardando par 650: HTTP response code: 403
# Error guardando par 651: HTTP response code: 403
# Error guardando par 652: HTTP response code: 403
# Error guardando par 653: HTTP response code: 403
# Error guardando par 654: HTTP response code: 403
# Error guardando par 655: HTTP response code: 403
# Error guardando par 656: HTTP response code: 403
# Error guardando par 657: HTTP response code: 403
# Error guardando par 658: HTTP response code: 403
# Error guardando par 659: HTTP response code: 403
# Error guardando par 660: HTTP response code: 403
# Error guardando par 661: HTTP response code: 403
# Error guardando par 662: HTTP response code: 403
# Error guardando par 663: HTTP response code: 403
# Error guardando par 664: HTTP response code: 403
# Error guardando par 665: HTTP response code: 403
# Error guardando par 666: HTTP response code: 403
# Error guardando par 667: HTTP response code: 403
# Error guardando par 668: HTTP response code: 403
# Error guardando par 669: HTTP response code: 403
# Error guardando par 670: HTTP response code: 403
# Error guardando par 671: HTTP response code: 403
# Error guardando par 672: HTTP response code: 403
# Error guardando par 673: HTTP response code: 403
# Error guardando par 674: HTTP response code: 403
# Error guardando par 675: HTTP response code: 403
# Error guardando par 676: HTTP response code: 403
# Error guardando par 677: HTTP response code: 403
# Error guardando par 678: HTTP response code: 403
# Error guardando par 679: HTTP response code: 403
# Error guardando par 680: HTTP response code: 403
# Error guardando par 681: HTTP response code: 403
# Error guardando par 682: HTTP response code: 403
# Error guardando par 683: HTTP response code: 403
# Error guardando par 684: HTTP response code: 403
# Error guardando par 685: HTTP response code: 403
# Error guardando par 686: HTTP response code: 403
# Error guardando par 687: HTTP response code: 403
# Error guardando par 688: HTTP response code: 403
# Error guardando par 689: HTTP response code: 403
# Error guardando par 690: HTTP response code: 403
# Error guardando par 691: HTTP response code: 403
# Error guardando par 692: HTTP response code: 403
# Error guardando par 693: HTTP response code: 403
# Error guardando par 694: HTTP response code: 403
# Error guardando par 695: HTTP response code: 403
# Error guardando par 696: HTTP response code: 403
# Error guardando par 697: HTTP response code: 403
# Error guardando par 698: HTTP response code: 403
# Error guardando par 699: HTTP response code: 403
# Error guardando par 700: HTTP response code: 403
# Error guardando par 701: HTTP response code: 403
# Error guardando par 702: HTTP response code: 403
# Error guardando par 703: HTTP response code: 403
# Error guardando par 704: HTTP response code: 403
# Error guardando par 705: HTTP response code: 403
# Error guardando par 706: HTTP response code: 403
# Error guardando par 707: HTTP response code: 403
# Error guardando par 708: HTTP response code: 403
# Error guardando par 709: HTTP response code: 403
# Error guardando par 710: HTTP response code: 403
# Error guardando par 711: HTTP response code: 403
# Error guardando par 712: HTTP response code: 403
# Error guardando par 713: HTTP response code: 403
# Error guardando par 714: HTTP response code: 403
# Error guardando par 715: HTTP response code: 403
# Error guardando par 716: HTTP response code: 403
# Error guardando par 717: HTTP response code: 403
# Error guardando par 718: HTTP response code: 403
# Error guardando par 719: HTTP response code: 403
# Error guardando par 720: HTTP response code: 403
# Error guardando par 721: HTTP response code: 403
# Error guardando par 722: HTTP response code: 403
# Error guardando par 723: HTTP response code: 403
# Error guardando par 724: HTTP response code: 403
# Error guardando par 725: HTTP response code: 403
# Error guardando par 726: HTTP response code: 403
# Error guardando par 727: HTTP response code: 403
# Error guardando par 728: HTTP response code: 403
# Error guardando par 729: HTTP response code: 403
# Error guardando par 730: HTTP response code: 403
# Error guardando par 731: HTTP response code: 403
# Error guardando par 732: HTTP response code: 403
# Error guardando par 733: HTTP response code: 403
# Error guardando par 734: HTTP response code: 403
# Error guardando par 735: HTTP response code: 403
# Error guardando par 736: HTTP response code: 403
# Error guardando par 737: HTTP response code: 403
# Error guardando par 738: HTTP response code: 403
# Error guardando par 739: HTTP response code: 403
# Error guardando par 740: HTTP response code: 403
# Error guardando par 741: HTTP response code: 403
# Error guardando par 742: HTTP response code: 403
# Error guardando par 743: HTTP response code: 403
# Error guardando par 744: HTTP response code: 403
# Error guardando par 745: HTTP response code: 403
# Error guardando par 746: HTTP response code: 403
# Error guardando par 747: HTTP response code: 403
# Error guardando par 748: HTTP response code: 403
# Error guardando par 749: HTTP response code: 403
# Error guardando par 750: HTTP response code: 403
# Error guardando par 751: HTTP response code: 403
# Error guardando par 752: HTTP response code: 403
# Error guardando par 753: HTTP response code: 403
# Error guardando par 754: HTTP response code: 403
# Error guardando par 755: HTTP response code: 403
# Error guardando par 756: HTTP response code: 403
# Error guardando par 757: HTTP response code: 403
# Error guardando par 758: HTTP response code: 403
# Error guardando par 759: HTTP response code: 403
# Error guardando par 760: HTTP response code: 403
# Error guardando par 761: HTTP response code: 403
# Error guardando par 762: HTTP response code: 403
# Error guardando par 763: HTTP response code: 403
# Error guardando par 764: HTTP response code: 403
# Error guardando par 765: HTTP response code: 403
# Error guardando par 766: HTTP response code: 403
# Error guardando par 767: HTTP response code: 403
# Error guardando par 768: HTTP response code: 403
# Error guardando par 769: HTTP response code: 403
# Error guardando par 770: HTTP response code: 403
# Error guardando par 771: HTTP response code: 403
# Error guardando par 772: HTTP response code: 403
# Error guardando par 773: HTTP response code: 403
# Error guardando par 774: HTTP response code: 403
# Error guardando par 775: HTTP response code: 403
# Error guardando par 776: HTTP response code: 403
# Error guardando par 777: HTTP response code: 403
# Error guardando par 778: HTTP response code: 403
# Error guardando par 779: HTTP response code: 403
# Error guardando par 780: HTTP response code: 403
# Error guardando par 781: HTTP response code: 403
# Error guardando par 782: HTTP response code: 403
# Error guardando par 783: HTTP response code: 403
# Error guardando par 784: HTTP response code: 403
# Error guardando par 785: HTTP response code: 403
# Error guardando par 786: HTTP response code: 403
# Error guardando par 787: HTTP response code: 403
# Error guardando par 788: HTTP response code: 403
# Error guardando par 789: HTTP response code: 403
# Error guardando par 790: HTTP response code: 403
# Error guardando par 791: HTTP response code: 403
# Error guardando par 792: HTTP response code: 403
# Error guardando par 793: HTTP response code: 403
# Error guardando par 794: HTTP response code: 403
# Error guardando par 795: HTTP response code: 403
# Error guardando par 796: HTTP response code: 403
# Error guardando par 797: HTTP response code: 403
# Error guardando par 798: HTTP response code: 403
# Error guardando par 799: HTTP response code: 403
# Error guardando par 800: HTTP response code: 403
# Error guardando par 801: HTTP response code: 403
# Error guardando par 802: HTTP response code: 403
# Error guardando par 803: HTTP response code: 403
# Error guardando par 804: HTTP response code: 403
# Error guardando par 805: HTTP response code: 403
# Error guardando par 806: HTTP response code: 403
# Error guardando par 807: HTTP response code: 403
# Error guardando par 808: HTTP response code: 403
# Error guardando par 809: HTTP response code: 403
# Error guardando par 810: HTTP response code: 403
# Error guardando par 811: HTTP response code: 403
# Error guardando par 812: HTTP response code: 403
